# %% [markdown]
# <a href="https://colab.research.google.com/github/emmalynnye-stack/gis-project-portfolio-geo441-541b/blob/main/basic-mapping/age-index-mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Querying Vector Data Tables**

# %% [markdown]
# Created by [Emmalyn Nye]
#
# [09/30/2025]

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ##**Part 1: Oldsters Map**

# %% [markdown]
# Below is a map of high age-index U.S. counties prepared following the Week 5 Assignment Guide.
#
# ```markdown
# [https://drive.google.com/file/d/155LcNeUqP9OorgfRWZpqDxR3XSqjGEgC/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=155LcNeUqP9OorgfRWZpqDxR3XSqjGEgC]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![oldsters map](https://drive.google.com/uc?export=view&id=155LcNeUqP9OorgfRWZpqDxR3XSqjGEgC)
# ```
#
# <mark>![oldsters map](https://drive.google.com/uc?export=view&id=155LcNeUqP9OorgfRWZpqDxR3XSqjGEgC)</mark>

# %% [markdown]
# ##**Part 2: Table Join**

# %% [markdown]
# Below is a screenshot of selected records in a joined table prepared following the Week 5 Assignment Guide.
#
#
# ```markdown
# [https://drive.google.com/file/d/1CUh9E3gEOOUcZqtIS6FJUkSEghsGndVc/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1CUh9E3gEOOUcZqtIS6FJUkSEghsGndVc]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![selected records](https://drive.google.com/uc?export=view&id=1CUh9E3gEOOUcZqtIS6FJUkSEghsGndVc)
# ```
#
# <mark>![selected records](https://drive.google.com/uc?export=view&id=1CUh9E3gEOOUcZqtIS6FJUkSEghsGndVc)</mark>

# %% [markdown]
# ##**Part 3: Soil Fertility Map**

# %% [markdown]
# Below is a map of soil fertility prepared following the Week 5 Assignment Guide.
#
# ```markdown
# [https://drive.google.com/file/d/1tf5R1z7SomoDpeXyViqn5O9jdPHUFNwN/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1tf5R1z7SomoDpeXyViqn5O9jdPHUFNwN]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![soil fertility map](https://drive.google.com/uc?export=view&id=1tf5R1z7SomoDpeXyViqn5O9jdPHUFNwN)
# ```
#
# <mark>![soil fertility map](https://drive.google.com/uc?export=view&id=1tf5R1z7SomoDpeXyViqn5O9jdPHUFNwN)</mark>

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link. <mark>**Submit the shareable link to Canvas for the Week 5 Assignment.**</mark>

# %% [markdown]
# ## **References**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
