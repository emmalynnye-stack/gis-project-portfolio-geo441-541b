# %% [markdown]
# <a href="https://colab.research.google.com/github/emmalynnye-stack/gis-project-portfolio-geo441-541b/blob/main/raster-data-visualization/oh-topography.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Raster Data Terrain Analysis**

# %% [markdown]
# Created by [Emmalyn Nye]
#
# [10/23/*2025*]

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ## **Part 1: Oxford Topography Map**

# %% [markdown]
# Below is a map of Oxford, Ohio's topography, prepared following the [Week 9 Assignment Guide](https://docs.google.com/document/d/1DT_0BKPsmqB9xtcc6IAaj-AdU21O1fyvQZhNYV6DipQ/edit?usp=sharing).
#
# ```markdown
# [https://drive.google.com/file/d/1wH01yAcztgbT4IA0yZsy3cekmC6ltobS/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1wH01yAcztgbT4IA0yZsy3cekmC6ltobS]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![ox topography](https://drive.google.com/uc?export=view&id=1wH01yAcztgbT4IA0yZsy3cekmC6ltobS)
# ```
#
# <mark>![ox topography](https://drive.google.com/uc?export=view&id=1wH01yAcztgbT4IA0yZsy3cekmC6ltobS)</mark>

# %% [markdown]
# ## **Part 2: Oxford Zonal Statistics Map**

# %% [markdown]
# Below is a map of Oxford, Ohio's parcels visualized by average slope, prepared following the [Week 9 Assignment Guide](https://docs.google.com/document/d/1DT_0BKPsmqB9xtcc6IAaj-AdU21O1fyvQZhNYV6DipQ/edit?usp=sharing).
#
# ```markdown
# [https://drive.google.com/file/d/1Eg8KtImNjkejALkc9Cvb4GI-6DNBy2Qo/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1Eg8KtImNjkejALkc9Cvb4GI-6DNBy2Qo]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![ox zonal stats](https://drive.google.com/uc?export=view&id=1Eg8KtImNjkejALkc9Cvb4GI-6DNBy2Qo)
# ```
#
# <mark>![ox zonal stats](https://drive.google.com/uc?export=view&id=1Eg8KtImNjkejALkc9Cvb4GI-6DNBy2Qo)</mark>

# %% [markdown]
# ## **Part 3: Reflection**
#
# *In a brief paragraph, compare the two maps you created. Describe the visual and data model differences between the DEM datasets visualized in the topology map and the zonal statistics calculated and appended to the parcel dataset in the second map.*
#
# <mark> [The first map, I showcased the topography of Oxford, OH by calculating the hillshade and slope of a digital elevation model (DEM) of campus (Data Source: DEM from USGS 3DEP 10m) This was done using the hillshade and slope geoprocessing tools. The second map was calculated using the calculated slope from the first map. I ran zonal statistics to identify parcels in Oxford with a relatively deep slope. This was done through summarizing the values of the parcel raster data set of Oxford using the slope as our input value raster, and calculating the mean of those two values.] </mark>

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 9 Assignment.**</mark>
